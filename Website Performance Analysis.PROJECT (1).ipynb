# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df =pd.read_csv("data-export (1).csv")
df
# Out:
#              # ----------------------------------------  \
# 0     Session primary channel group (Default channel...
# 1                                                Direct
# 2                                        Organic Social
# 3                                                Direct
# 4                                        Organic Social
# ...                                                 ...
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
# 3182                                         Unassigned
#
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0     Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                   2024041623        237        300               144
# 2                   2024041719        208        267               132
# ...

# %%
df.head()
# Out:
#           # ----------------------------------------  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
#                  Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0  Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                2024041623        237        300               144
# 2                2024041719        208        267               132
# 3                2024041723        188        233               115
# 4                2024041718        187        256               125
#
#                             Unnamed: 5                 Unnamed: 6  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# ...

# %%
df.columns = df.iloc[0]
df.head()
# Out:
# 0 Session primary channel group (Default channel group)  \
# 0  Session primary channel group (Default channel...
# 1                                             Direct
# 2                                     Organic Social
# 3                                             Direct
# 4                                     Organic Social
#
# 0  Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions  \
# 0  Date + hour (YYYYMMDDHH)  Users  Sessions  Engaged sessions
# 1                2024041623    237       300               144
# 2                2024041719    208       267               132
# 3                2024041723    188       233               115
# 4                2024041718    187       256               125
#
# 0  Average engagement time per session  Engaged sessions per user  \
# 0  Average engagement time per session  Engaged sessions per user
# 1                   47.526666666666700         0.6075949367088610
# ...

# %%
df = df.drop(index = 0)
df = df.reset_index(drop = True)
df
# Out:
# 0    Session primary channel group (Default channel group)  \
# 0                                                Direct
# 1                                        Organic Social
# 2                                                Direct
# 3                                        Organic Social
# 4                                        Organic Social
# ...                                                 ...
# 3177                                         Unassigned
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
#
# 0    Date + hour (YYYYMMDDHH) Users Sessions Engaged sessions  \
# 0                  2024041623   237      300              144
# 1                  2024041719   208      267              132
# 2                  2024041723   188      233              115
# ...

# %%
df.columns =['Channel Group','DateHour','Users','Sessions', 'Engaged sessions',	'Average engagement time per session',	'Engaged sessions per user','Events per session','Engagement rate',	'Event count']

# %%
df.head()
# Out:
#     Channel Group    DateHour Users Sessions Engaged sessions  \
# 0          Direct  2024041623   237      300              144
# 1  Organic Social  2024041719   208      267              132
# 2          Direct  2024041723   188      233              115
# 3  Organic Social  2024041718   187      256              125
# 4  Organic Social  2024041720   175      221              112
#
#   Average engagement time per session Engaged sessions per user  \
# 0                  47.526666666666700        0.6075949367088610
# 1                   32.09737827715360        0.6346153846153850
# 2                   39.93991416309010        0.6117021276595740
# 3                         32.16015625        0.6684491978609630
# 4                  46.918552036199100                      0.64
#
#   Events per session      Engagement rate Event count
# 0  4.673333333333330                 0.48        1402
# 1  4.295880149812730   0.4943820224719100        1147
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Channel Group                        3182 non-null   object
#  1   DateHour                             3182 non-null   object
#  2   Users                                3182 non-null   object
#  3   Sessions                             3182 non-null   object
#  4   Engaged sessions                     3182 non-null   object
#  5   Average engagement time per session  3182 non-null   object
#  6   Engaged sessions per user            3182 non-null   object
#  7   Events per session                   3182 non-null   object
#  8   Engagement rate                      3182 non-null   object
#  9   Event count                          3182 non-null   object
# dtypes: object(10)
# memory usage: 248.7+ KB

# %%
df['DateHour'] = pd.to_datetime(df['DateHour'], format ='%Y%m%d%H', errors ='coerce')
df
# Out:
#        Channel Group            DateHour Users Sessions Engaged sessions  \
# 0             Direct 2024-04-16 23:00:00   237      300              144
# 1     Organic Social 2024-04-17 19:00:00   208      267              132
# 2             Direct 2024-04-17 23:00:00   188      233              115
# 3     Organic Social 2024-04-17 18:00:00   187      256              125
# 4     Organic Social 2024-04-17 20:00:00   175      221              112
# ...              ...                 ...   ...      ...              ...
# 3177      Unassigned 2024-04-28 06:00:00     0        1                0
# 3178      Unassigned 2024-04-30 05:00:00     0        1                0
# 3179      Unassigned 2024-04-30 06:00:00     0        1                0
# 3180      Unassigned 2024-05-01 05:00:00     0        1                0
# 3181      Unassigned 2024-05-03 07:00:00     0        1                0
#
#      Average engagement time per session Engaged sessions per user  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Channel Group                        3182 non-null   object
#  1   DateHour                             3182 non-null   datetime64[ns]
#  2   Users                                3182 non-null   object
#  3   Sessions                             3182 non-null   object
#  4   Engaged sessions                     3182 non-null   object
#  5   Average engagement time per session  3182 non-null   object
#  6   Engaged sessions per user            3182 non-null   object
#  7   Events per session                   3182 non-null   object
#  8   Engagement rate                      3182 non-null   object
#  9   Event count                          3182 non-null   object
# dtypes: datetime64[ns](1), object(9)
# memory usage: 248.7+ KB

# %%
numeric_cols = df.columns.drop(['Channel Group','DateHour'])
df[numeric_cols] = df[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 10 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Channel Group                        3182 non-null   object
#  1   DateHour                             3182 non-null   datetime64[ns]
#  2   Users                                3182 non-null   int64
#  3   Sessions                             3182 non-null   int64
#  4   Engaged sessions                     3182 non-null   int64
#  5   Average engagement time per session  3182 non-null   float64
#  6   Engaged sessions per user            3182 non-null   float64
#  7   Events per session                   3182 non-null   float64
#  8   Engagement rate                      3182 non-null   float64
#  9   Event count                          3182 non-null   int64
# dtypes: datetime64[ns](1), float64(4), int64(4), object(1)
# ...

# %%
df['Hour'] = df['DateHour'].dt.hour
df
# Out:
#        Channel Group            DateHour  Users  Sessions  Engaged sessions  \
# 0             Direct 2024-04-16 23:00:00    237       300               144
# 1     Organic Social 2024-04-17 19:00:00    208       267               132
# 2             Direct 2024-04-17 23:00:00    188       233               115
# 3     Organic Social 2024-04-17 18:00:00    187       256               125
# 4     Organic Social 2024-04-17 20:00:00    175       221               112
# ...              ...                 ...    ...       ...               ...
# 3177      Unassigned 2024-04-28 06:00:00      0         1                 0
# 3178      Unassigned 2024-04-30 05:00:00      0         1                 0
# 3179      Unassigned 2024-04-30 06:00:00      0         1                 0
# 3180      Unassigned 2024-05-01 05:00:00      0         1                 0
# 3181      Unassigned 2024-05-03 07:00:00      0         1                 0
#
# ...

# %%
df.describe()
# Out:
#                             DateHour        Users     Sessions  \
# count                           3182  3182.000000  3182.000000
# mean   2024-04-20 01:17:07.278441216    41.935889    51.192646
# min              2024-04-06 00:00:00     0.000000     1.000000
# 25%              2024-04-13 02:15:00    20.000000    24.000000
# 50%              2024-04-20 02:00:00    42.000000    51.000000
# 75%              2024-04-26 22:00:00    60.000000    71.000000
# max              2024-05-03 23:00:00   237.000000   300.000000
# std                              NaN    29.582258    36.919962
#
#        Engaged sessions  Average engagement time per session  \
# count       3182.000000                          3182.000000
# mean          28.325581                            66.644581
# min            0.000000                             0.000000
# 25%           13.000000                            32.103034
# 50%           27.000000                            49.020202
# ...

# %% [markdown]
# # sessions and users over time period

# %%
df.groupby('DateHour')[['Users','Sessions']].sum()
# Out:
#                      Users  Sessions
# DateHour
# 2024-04-06 00:00:00    197       270
# 2024-04-06 01:00:00    107       142
# 2024-04-06 02:00:00    115       142
# 2024-04-06 03:00:00     93       122
# 2024-04-06 04:00:00     79       102
# ...                    ...       ...
# 2024-05-03 19:00:00    264       324
# 2024-05-03 20:00:00    273       327
# 2024-05-03 21:00:00    315       374
# 2024-05-03 22:00:00    304       374
# 2024-05-03 23:00:00    216       256
#
# [672 rows x 2 columns]

# %%
sns.set(style ='whitegrid')
plt.figure(figsize =(10,5))
df.groupby('DateHour')[['Users','Sessions']].sum().plot(ax = plt.gca())
plt.title('Sessions and Users OverTime')
plt.xlabel('Date_hour')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Total users by Channel

# %%
plt.figure(figsize =(8,5))
sns.barplot(data = df, x='Channel Group', y='Users', estimator= np.sum, palette= 'magma')
plt.title('Total Users Vs Channel')
plt.xticks(rotation = 45)
plt.show()

# %% [markdown]
# # Average Engagement time by Channel

# %%
df.head()
# Out:
#     Channel Group            DateHour  Users  Sessions  Engaged sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.673333         0.480000         1402    23
# ...

# %%
plt.figure(figsize=(8,5))
sns.barplot(data=df, x='Channel Group', y='Average engagement time per session', palette='viridis')
plt.title('Average Engagement Time by Channels')
plt.xticks(rotation =45)
plt.show()

# %% [markdown]
# # Engagement rate distribution by channel

# %%
plt.figure(figsize=(10,5))
sns.boxplot(data = df, x ='Channel Group', y='Engagement rate', palette='coolwarm')
plt.title('Engagement Rate Distribution By Channels')
plt.xticks(rotation =45)
plt.show()

# %% [markdown]
# # Engaged Vs Non-engaged

# %%
df.head()
# Out:
#     Channel Group            DateHour  Users  Sessions  Engaged sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.673333         0.480000         1402    23
# ...

# %%
df_sessions = df.groupby('Channel Group')[['Sessions','Engaged sessions']].sum().reset_index()
df_sessions
# Out:
#     Channel Group  Sessions  Engaged sessions
# 0          Direct     37203             17243
# 1           Email         3                 1
# 2  Organic Search     33372             19425
# 3  Organic Social     60627             32697
# 4   Organic Video       141               109
# 5        Referral     30990             20653
# 6      Unassigned       559                 4

# %%
df_sessions['Non_engaged'] = df_sessions['Sessions'] - df_sessions['Engaged sessions']

# %%
df_sessions_melted = df_sessions.melt( id_vars='Channel Group', value_vars =['Engaged sessions','Non_engaged'])
df_sessions_melted
# Out:
#      Channel Group          variable  value
# 0           Direct  Engaged sessions  17243
# 1            Email  Engaged sessions      1
# 2   Organic Search  Engaged sessions  19425
# 3   Organic Social  Engaged sessions  32697
# 4    Organic Video  Engaged sessions    109
# 5         Referral  Engaged sessions  20653
# 6       Unassigned  Engaged sessions      4
# 7           Direct       Non_engaged  19960
# 8            Email       Non_engaged      2
# 9   Organic Search       Non_engaged  13947
# 10  Organic Social       Non_engaged  27930
# 11   Organic Video       Non_engaged     32
# 12        Referral       Non_engaged  10337
# 13      Unassigned       Non_engaged    555

# %%
plt.figure(figsize=(8,5))

sns.barplot( data= df_sessions_melted, x='Channel Group', y='value', hue='variable')
plt.title('Engaged & Non-Engaged')
plt.xticks(rotation =45)
plt.show()

# %% [markdown]
# # traffic by hour and channel

# %%
df.head()
# Out:
#     Channel Group            DateHour  Users  Sessions  Engaged sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.673333         0.480000         1402    23
# ...

# %%
heatmap_data = df.groupby(['Hour','Channel Group'])['Sessions'].sum().unstack().fillna(0)
heatmap_data
# Out:
# Channel Group  Direct  Email  Organic Search  Organic Social  Organic Video  \
# Hour
# 0              1684.0    0.0          1311.0          3917.0            6.0
# 1              1196.0    0.0           984.0          2108.0            5.0
# 2               887.0    1.0           804.0          1537.0            2.0
# 3               771.0    0.0           606.0          1249.0            2.0
# 4               666.0    1.0           535.0          1081.0            2.0
# 5               679.0    0.0           506.0           951.0            1.0
# 6               768.0    0.0           639.0          1171.0            1.0
# 7               889.0    0.0           778.0          1524.0            2.0
# 8              1078.0    0.0           938.0          1886.0            4.0
# 9              1347.0    0.0          1269.0          2390.0            4.0
# 10             1621.0    0.0          1649.0          2834.0            9.0
# ...

# %%
plt.figure(figsize =(12,6))

sns.heatmap(heatmap_data, cmap='magma',annot =True, fmt='.0f',linewidths=.5)
plt.title('Traffic by Hour & Channel')
plt.xlabel('Channel Group')
plt.ylabel('Hours in a Day')
plt.show()
